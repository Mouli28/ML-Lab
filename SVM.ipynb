# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

iris = datasets.load_iris()

X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svm_classifier = SVC(kernel='linear', C=1.0, random_state=42)

svm_classifier.fit(X_train_scaled, y_train)

y_pred = svm_classifier.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9777777777777777

# %%
print(svm_classifier.predict(X_test_scaled))
# Out:
# [1 0 2 1 1 0 1 2 2 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]

# %%
print(iris)

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

X_train_2d = X_train_scaled[:, :2]

svm_classifier.fit(X_train_2d, y_train)

plot_decision_regions(X_train_2d, y_train, clf=svm_classifier, legend=2)

plt.show()
